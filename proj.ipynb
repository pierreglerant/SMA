# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import mesa
from mesa import Agent, Model
from mesa.space import MultiGrid
import random
import solara
from mesa.visualization import SolaraViz, make_space_component

# %% [markdown]
# ### Agents

# %%
def get_pos_delta(curr_pos, next_pos):
    """
    Calcule et retourne la différence (delta) entre deux positions.
    """
    return (next_pos[0] - curr_pos[0], next_pos[1] - curr_pos[1])

def get_new_pos(curr_pos, delta):
    """
    Retourne une nouvelle position en ajoutant le delta à la position actuelle.
    """
    return (curr_pos[0] + delta[0], curr_pos[1] + delta[1])

class RobotAgent(Agent):
    """
    Classe de base pour les robots, étend la classe Agent de Mesa.
    Chaque robot possède un inventaire, une liste d'éléments prêts à être livrés et un niveau.
    """
    
    def __init__(self, model):
        super().__init__(model)
        self.knowledge = lambda: 0  # Stocke les informations perçues (sera enrichi par la suite)
        self.inventory = []  # Inventaire pour stocker les éléments collectés
        self.ready_to_deliver = []  # Liste des éléments traités prêts à être déposés
        self.inventory_full = False  # Indicateur si l'inventaire est plein
        self.level = 0  # Niveau du robot (à définir dans les sous-classes)
    
    def get_level(self):
        """
        Retourne le niveau du robot.
        """
        return self.level
    
    def process_waste(self):
        """
        Traite les déchets en retirant deux éléments de l'inventaire et en ajoutant le résultat dans la liste ready_to_deliver.
        """
        self.ready_to_deliver.append(self.model.process_waste(self.inventory.pop(), self.inventory.pop()))
    
    def perceive(self):
        """
        Permet au robot de percevoir son environnement :
          - Vérifie si l'inventaire est plein.
          - Récupère les cellules voisines (en incluant la position actuelle).
          - Calcule les deltas par rapport à la position actuelle.
          - Stocke le contenu des cellules voisines.
          - Identifie les mouvements possibles en fonction de la présence d'un objet Radioactivity de niveau correspondant.
        """
        if len(self.inventory) > 1:
            self.inventory_full = True
        else:
            self.inventory_full = False
            
        # Récupère les positions voisines selon le voisinage de Moore
        possible_moves = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=True
        )

        # Stocke les deltas de positions par rapport à la position actuelle
        self.knowledge.neighbors = [get_pos_delta(self.pos, possible_step) for possible_step in possible_moves]

        # Stocke le contenu de chaque cellule voisine
        self.knowledge.close_contents = {}
        for possible_step in self.knowledge.neighbors:
            self.knowledge.close_contents[possible_step] = self.model.grid.get_cell_list_contents([get_new_pos(self.pos, possible_step)])

        # Identifie les mouvements possibles basés sur la présence de Radioactivity correspondant au niveau du robot
        self.knowledge.possible_moves = []
        for n in self.knowledge.neighbors:
            for a in self.knowledge.close_contents[n]:
                if isinstance(a, Radioactivity):
                    if a.get_radioactivity_level() == self.level:
                        self.knowledge.possible_moves.append(n)
    
    def deliberate(self):
        """
        Le robot reste dans sa zone et, dès qu'il a le nombre de déchets requis,
        il se déplace vers la cellule la plus à l'est de sa zone. Une fois sur place, il exécute "DROP"
        pour déposer le déchet sur la case immédiatement à droite de la frontière est.
        """
        grid_width = self.model.w
        # Pour définir la zone de chaque robot :
        if self.get_level() == 1:
            # Zone 1 : colonnes 0 à (w//3 - 1)
            target_x = (self.model.w // 3) - 1  # position la plus à l'est dans la zone
            deposit_x = self.model.w // 3         # cellule juste à droite de la zone 1
            required = 2
        elif self.get_level() == 2:
            # Zone 2 : colonnes w//3 à (2*w//3 - 1)
            target_x = (2 * (self.model.w // 3)) - 1  # position la plus à l'est dans la zone
            deposit_x = 2 * (self.model.w // 3)         # cellule juste à droite de la zone 2
            required = 2
        else:  # niveau 3
            # Zone 3 : colonnes 2*w//3 à (w - 1) (déjà la zone de décharge)
            target_x = self.model.w - 1  # position la plus à l'est dans la zone (décharge)
            deposit_x = self.model.w - 1 # pour le robot rouge, le dépôt se fait sur sa case
            required = 1

        # Si le robot dispose du nombre requis de déchets
        if len(self.inventory) >= required:
            # Pour les robots verts et jaunes, transformer si ce n'est pas déjà fait
            if self.get_level() in [1, 2] and not self.ready_to_deliver:
                self.process_waste()
            # Si le robot n'est pas encore à la position cible dans sa zone, avancer vers l'est
            if self.pos[0] < target_x:
                return (1, 0)
            else:
                # Une fois à la frontière est, déposer le déchet dans la cellule de dépôt
                return "DROP"

        # Sinon, tenter de ramasser un déchet dans la cellule actuelle
        close_waste = {}
        for delta in self.knowledge.possible_moves:
            waste_list = [w for w in self.knowledge.close_contents[delta]
                        if isinstance(w, Waste) and w.get_level() == self.get_level()]
            if waste_list:
                close_waste[delta] = waste_list

        if (0, 0) in close_waste:
            return "PICK"
        if close_waste:
            return random.choice(list(close_waste.keys()))
        return random.choice(self.knowledge.possible_moves)


    
    def step(self):
        """
        Cycle d'action du robot : percevoir l'environnement, délibérer sur l'action à prendre et exécuter cette action.
        """
        self.perceive()
        action = self.deliberate()
        self.model.perform_action(self, action)

class GreenRobotAgent(RobotAgent):
    """
    Robot de niveau vert.
    """
    def __init__(self, model):
        super().__init__(model)
        self.level = 1

class YellowRobotAgent(RobotAgent):
    """
    Robot de niveau jaune.
    """
    def __init__(self, model):
        super().__init__(model)
        self.level = 2

class RedRobotAgent(RobotAgent):
    """
    Robot de niveau rouge.
    """
    def __init__(self, model):
        super().__init__(model)
        self.level = 3

# %% [markdown]
# ### Objects

# %%
class Radioactivity(Agent):
    def __init__(self, model, level=1):
        super().__init__(model)
        self.level = level  # Niveau de radioactivité

    def get_radioactivity_level(self):
        """
        Retourne le niveau de radioactivité.
        """
        return self.level
    
    def step(self):
        # Pas d'action spécifique pour l'instant.
        pass

class Waste(Agent):
    def __init__(self, model, level=1):
        super().__init__(model)
        self.level = level  # Niveau associé au déchet

    def get_level(self):
        """
        Retourne le niveau du déchet.
        """
        return self.level
    
    def step(self):
        # Pas d'action spécifique pour l'instant.
        pass

class DisposalZone(Agent):
    def __init__(self, model):
        super().__init__(model)
    
    def step(self):
        # Pas d'action spécifique pour la zone de décharge.
        pass

# %% [markdown]
# ### Model

# %%
class RobotMission(Model):
    def __init__(self, n_agents=1, n_zone=3, n_waste=2, w=16, h=10, seed=None):
        super().__init__(seed=seed)
        
        self.n_agents = n_agents      # Nombre d'agents robots par type
        self.n_zone = n_zone          # Nombre de zones (non utilisé directement ici)
        self.n_waste = n_waste        # Nombre de déchets par niveau
        self.w = w                    # Nombre de colonnes de la grille
        self.h = h                    # Nombre de lignes de la grille

        # Création de la grille multi-agents
        self.grid = MultiGrid(self.w, self.h, torus=False)

        # Placement de la radioactivité de niveau 1
        Radioactivity.create_agents(model=self, n=(self.w // 3 * self.h), level=1)
        i = 0
        j = 0
        # Placement itératif des agents Radioactivity niveau 1 sur la grille
        for agent in self.agents_by_type[type(Radioactivity(Model()))]:
            self.grid.place_agent(agent, (i % w, j % h))
            j += 1
            if j % h == 0:
                i += 1

        # Placement de la radioactivité de niveau 2
        Radioactivity.create_agents(model=self, n=(self.w // 3 * self.h), level=2)
        for agent in self.agents_by_type[type(Radioactivity(Model()))]:
            if agent.get_radioactivity_level() == 2:    
                self.grid.place_agent(agent, (i % w, j % h))
                j += 1
                if j % h == 0:
                    i += 1

        # Placement de la radioactivité de niveau 3
        Radioactivity.create_agents(model=self, n=(self.w // 3 * self.h), level=3)
        for agent in self.agents_by_type[type(Radioactivity(Model()))]:
            if agent.get_radioactivity_level() == 3:    
                self.grid.place_agent(agent, (i % w, j % h))
                j += 1
                if j % h == 0:
                    i += 1

        # Création et placement des robots de différents niveaux/couleurs
        GreenRobotAgent.create_agents(self, n=self.n_agents)
        YellowRobotAgent.create_agents(self, n=self.n_agents)
        RedRobotAgent.create_agents(self, n=self.n_agents)

        # Placement aléatoire des robots dans leur zone de départ en fonction de leur niveau
        for agent in self.agents:
            if isinstance(agent, RobotAgent):
                lvl = agent.get_level()
                w_r = random.randint((lvl - 1) * (w // 3), lvl * (w // 3) - 1)
                h_r = random.randint(0, h - 1)
                self.grid.place_agent(agent, (w_r, h_r))

        # Création et placement des déchets pour chaque niveau
        Waste.create_agents(self, n=self.n_waste, level=1)
        Waste.create_agents(self, n=self.n_waste, level=2)
        Waste.create_agents(self, n=self.n_waste, level=3)

        for agent in self.agents_by_type[type(Waste(Model()))]:
            lvl = agent.get_level()
            w_w = random.randint((lvl - 1) * (w // 3), lvl * (w // 3) - 1)
            h_w = random.randint(0, h - 1)
            self.grid.place_agent(agent, (w_w, h_w))

        # Création et placement des zones de décharge (DisposalZone)
        DisposalZone.create_agents(self, n=self.h)
        h_dz = 0
        for agent in self.agents_by_type[type(DisposalZone(Model()))]:
            self.grid.place_agent(agent, (w - 1, h_dz))
            h_dz += 1

    def perform_action(self, agent, action):
        if action == "PICK":
            waste_candidates = [w for w in self.grid.get_cell_list_contents([agent.pos]) if isinstance(w, Waste)]
            if waste_candidates:
                waste = waste_candidates[0]
                agent.inventory.append(waste)
                self.grid.remove_agent(waste)
            else:
                print("Aucun déchet à ramasser sur cette case.")
        
        elif action == "DROP":
            if agent.get_level() in [1, 2]:
                if agent.ready_to_deliver:
                    # Calcul du dépôt pour un robot vert ou jaune
                    if agent.get_level() == 1:
                        deposit_x = self.w // 3
                    else:  # niveau 2
                        deposit_x = 2 * (self.w // 3)
                    deposit_pos = (deposit_x, agent.pos[1])
                    waste = agent.ready_to_deliver.pop()
                    self.grid.place_agent(waste, deposit_pos)
                else:
                    print("Aucun déchet traité pour robot de niveau", agent.get_level())
            elif agent.get_level() == 3:
                if agent.inventory:
                    deposit_pos = (self.w - 1, agent.pos[1])
                    waste = agent.inventory.pop(0)
                    self.grid.place_agent(waste, deposit_pos)
                else:
                    print("Aucun déchet à déposer pour le robot rouge.")
        
        else:
            self.grid.move_agent(agent, get_new_pos(agent.pos, action))

    
    def process_waste(self, waste1, waste2):
        """
        Combine deux déchets de même niveau pour produire un déchet de niveau supérieur.
        """
        if waste1.get_level() == waste2.get_level():
            w = Waste.create_agents(self, 1, level=(waste1.get_level() + 1))
        return w[0]
    
    def step(self):
        """
        Exécute un pas de simulation en ordonnant à chaque agent de réaliser son action.
        """
        self.agents.shuffle_do("step")

# %% [markdown]
# ### Visualization

# %%
def agent_portrayal(agent):
    # Détermine la représentation graphique de l'agent selon son type et son niveau.
    
    if isinstance(agent, Radioactivity):
        # Représentation de la radioactivité : couleur et taille varient selon le niveau.
        if agent.get_radioactivity_level() == 1:
            return {
                "color": "#00FF0080",  # Vert translucide
                "size": 500,
                "marker": "s",        # Carré
            }
        elif agent.get_radioactivity_level() == 2:
            return {
                "color": "#FFFF0080",  # Jaune translucide
                "size": 500,
                "marker": "s",
            }
        elif agent.get_radioactivity_level() == 3:
            return {
                "color": "#FF000080",  # Rouge translucide
                "size": 500,
                "marker": "s",
            }
    
    if isinstance(agent, RobotAgent):
        # Représentation des robots selon leur niveau (couleur et taille)
        if agent.get_level() == 1:
            return {
                "color": "green",
                "size": 100,
            }
        if agent.get_level() == 2:
            return {
                "color": "orange",
                "size": 100,
            }
        if agent.get_level() == 3:
            return {
                "color": "red",
                "size": 100,
            }
    
    if isinstance(agent, Waste):
        # Représentation des déchets avec un marqueur "X" ; la couleur indique le niveau.
        if agent.get_level() == 1:
            return {
                "color": "green",
                "size": 50,
                "marker": "X"
            }
        if agent.get_level() == 2:
            return {
                "color": "orange",
                "size": 50,
                "marker": "X"
            }
        if agent.get_level() == 3:
            return {
                "color": "red",
                "size": 50,
                "marker": "X"
            }
        if agent.get_level() == 4:
            return {
                "color": "black",
                "size": 50,
                "marker": "X"
            }
    
    if isinstance(agent, DisposalZone):
        # Représentation de la zone de décharge : grand carré gris.
        return {
            "color": "gray",
            "size": 500,
            "marker": "s"
        }
    
# Paramètres du modèle pour l'interface de configuration
model_params = {
    "n_zone": 1,
    "n_agents": {
        "type": "SliderInt",
        "value": 1,
        "label": "Number of agents:",
        "min": 1,
        "max": 5,
        "step": 1
    },
    "n_waste": 1,
    "w": 10,
    "h": 10,
}

# Création de l'instance du modèle RobotMission
mod = RobotMission()

# Création du composant graphique de la grille via la fonction de représentation d'agents
SpaceGraph = make_space_component(agent_portrayal)

# Configuration et création de la page de visualisation avec SolaraViz
page = SolaraViz(
    mod,
    components=[SpaceGraph],
    model_params=model_params
)

page  # Affiche la page Solara pour interagir avec la simulation
# Out:
# Cannot show ipywidgets in text

# %%
mod = RobotMission()
mod.step()
